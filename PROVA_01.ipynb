# %%
#Desenvolva um script em linguagem python nesta célula inicial para resolver o seguinte problema:
#VOCÊ DEVE RECEBER 3 VALORES INTEIROS POSITIVOS. E DEVE RETORNAR A MÉDIA ARITIMÉTRICA DOS MAIORES VALORES.

# Recebendo os três valores inteiros positivos
a = int(input("Digite o primeiro valor inteiro positivo: "))
b = int(input("Digite o segundo valor inteiro positivo: "))
c = int(input("Digite o terceiro valor inteiro positivo: "))

# Calculando a média aritmética dos maiores valores
if a >= b and a >= c:
    maior1 = a
    if b >= c:
        maior2 = b
    else:
        maior2 = c
elif b >= a and b >= c:
    maior1 = b
    if a >= c:
        maior2 = a
    else:
        maior2 = c
else:
    maior1 = c
    if a >= b:
        maior2 = a
    else:
        maior2 = b

media = (maior1 + maior2) / 2

# Imprimindo o resultado
print("A média aritmética dos dois maiores valores é:", media)
# Out:
# Digite o primeiro valor inteiro positivo:  2
# Digite o segundo valor inteiro positivo:  5
# Digite o terceiro valor inteiro positivo:  9
# A média aritmética dos dois maiores valores é: 7.0
